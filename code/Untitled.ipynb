# %%
import matplotlib as mpl
import matplotlib.colors as colors
import matplotlib.cbook as cbook
from matplotlib import cm
res = np.load('res.npy')

# %%
res.max()
# Out:
# -124265863380.36958

# %%
alphas[61], L_stars[23]
# Out:
# (-0.38, 1.4508287784959312e+41)

# %%
alphas, L_stars = np.linspace(-0.99, 0.0, 100), np.logspace(40, 45, 100)
log_L = np.linspace(40, 45, 100)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(np.linspace(40, 45, 100), alphas, np.exp(res/1e10+ 20)/4e2, norm=colors.PowerNorm(gamma=10),
                       cmap='viridis', shading='auto')
ax.scatter(log_L[23], alphas[61],color='red')
ax.annotate("$\\alpha=-0.38$\n$L^*=1.45\\times 10 ^ {41}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^6)=5334.49$",
            xy=(log_L[23], alphas[61]),
            xytext=(40.1, -0.67), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")

#fig.colorbar(img, ax=ax)
fig
plt.tight_layout()
fig.savefig('MLE N=n 1e6.jpeg', dpi=300)

# %%
res1 = np.load('res1.npy')
import matplotlib as mpl
alphas1 = np.linspace(-0.99, 0.5, 15)
L_stars1 = np.logspace(39, 45, 15)
log_L1 = np.linspace(39, 45, 15)

# %%
log_L1[5], alphas1[6]
# Out:
# (41.142857142857146, -0.3514285714285714)

# %%
res6 = np.load('res6.npy')
alphas6 = np.linspace(-0.99, 0., 15)
L_stars6 = np.logspace(40, 45, 15)
log_L6 = np.linspace(40, 45, 15)

# %%
10**log_L6[4], alphas6[8]
# Out:
# (2.6826957952797384e+41, -0.42428571428571427)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L1, alphas1, np.exp(res6/1e10+27)/4e2,cmap=mpl.cm.viridis,
                norm=colors.PowerNorm(gamma=10), shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L6[4], alphas6[8], color='red')
ax.annotate("$\\alpha=-0.42$\n$L^*=2.7\\times 10 ^ {41}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^5)=3.8 \\times 10^{8}$",
            xy=(log_L1[4], alphas1[8]),
            xytext=(40, -0.79), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 1e5.jpeg', dpi=300)

# %%
res7 = np.load('res7.npy')

# %%
10**log_L6[6], alphas6[6]
# Out:
# (1.3894954943731474e+42, -0.5657142857142857)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L1, alphas1, np.exp(res6/1e10+27)/4e2,cmap=mpl.cm.viridis, norm=colors.PowerNorm(gamma=10),
                shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L6[6], alphas6[6], color='red')
ax.annotate("$\\alpha=-0.42$\n$L^*=1.4\\times 10 ^ {42}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^4)=1.2 \\times 10^{9}$",
            xy=(log_L1[4], alphas1[8]),
            xytext=(40, -0.79), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 1e4.jpeg', dpi=300)

# %%
res2 = np.load('res2.npy')
alphas2 = np.linspace(-0.99, 0., 15)
L_stars2 = np.logspace(40, 45, 15)
log_L2 = np.linspace(40, 45 ,15)

# %%
5334.45
# Out:
# 5334.45

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L2, alphas2, np.exp(res2/1e10+27)/4e2,cmap=mpl.cm.viridis, shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L2[2], alphas2[10], color='red')
ax.annotate("$\\alpha=-0.28$\n$L^*=5.18\\times 10 ^ {40}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^7)=1.5\\times10^{-45}$",
            xy=(log_L2[2], alphas2[10]),
            xytext=(39.9, -0.6), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 1e7.jpeg', dpi=300)

# %%
res3 = np.load('res3.npy')
alphas3 = np.linspace(-0.99, 0., 15)
L_stars3 = np.logspace(40, 45, 15)
log_L3 = np.linspace(40, 45 ,15)

# %%
res3.max()/1e10
# Out:
# -6.2141173992584555

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L3, alphas3, np.exp(res3/1e10+27)/4e2,
                cmap=mpl.cm.viridis, shading='auto',
norm=colors.PowerNorm(gamma=10))
#fig.colorbar(img, ax=ax)
ax.scatter(log_L2[4], alphas2[8], color='red')
ax.annotate("$\\alpha=-0.42$\n$L^*=5.18\\times 10 ^ {40}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=5n\\times10^5)=2.7\\times10^{6}$",
            xy=(log_L2[4], alphas2[8]),
            xytext=(40.3, -0.7), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 5e5.jpeg', dpi=300)

# %%
res4 = np.load('res4.npy')
alphas4 = np.linspace(-0.99, 0., 15)
L_stars4 = np.logspace(40, 45, 15)
log_L4 = np.linspace(40, 45 ,15)

# %%
res4.argmax()
# Out:
# 124

# %%
L_stars[4], alphas4[8]
# Out:
# (1.5922827933410873e+40, -0.42428571428571427)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L4, alphas4, np.exp(res4/1e10+27)/4e2,cmap=mpl.cm.viridis,
                norm=colors.PowerNorm(gamma=10),
                shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L2[4], alphas2[8], color='red')
ax.annotate("$\\alpha=-0.42$\n$L^*=5.18\\times 10 ^ {40}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=3n\\times10^5)=3.2\\times10^{7}$",
            xy=(log_L2[4], alphas2[8]),
            xytext=(40.3, -0.7), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 3e5.jpeg', dpi=300)

# %%
res5 = np.load('res5.npy')
alphas5 = np.linspace(-0.99, 0., 15)
L_stars5 = np.logspace(40, 45, 15)
log_L5 = np.linspace(40, 45 ,15)

# %%
L_stars5[4], alphas2[8]
# Out:
# (2.6826957952797384e+41, -0.42428571428571427)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L4, alphas4, np.exp(res4/1e10+27)/4e2,cmap=mpl.cm.viridis,
                norm=colors.PowerNorm(gamma=10),
                shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L2[4], alphas2[8], color='red')
ax.annotate("$\\alpha=-0.42$\n$L^*=2.68\\times 10 ^ {41}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=2n\\times10^5)=1.1\\times10^{8}$",
            xy=(log_L2[4], alphas2[8]),
            xytext=(40.3, -0.7), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 2e5.jpeg', dpi=300)

# %%
(np.exp(res5/1e10+27)/4e2).max()
# Out:
# 110690904.98184142

# %%
(np.exp(res7/1e10+27)/4e2).max()
# Out:
# 1173887913.9894974

# %%
(np.exp(res4/1e10+27)/4e2).max()
# Out:
# 31948661.40369201

# %%
(np.exp(res/1e10+27)/4e2).max()
# Out:
# 5334.492938319166

# %%
(np.exp(res6/1e10+27)/4e2).max()
# Out:
# 383505158.193673

# %%
(np.exp(res1/1e10+27)/4e2).max()
# Out:
# 5334.45515847779

# %%
(np.exp(res9/1e10+27)/4e2).max()
# Out:
# 1329526289.3400588

# %%
(np.exp(res2/1e10+27)/4e2).max()
# Out:
# 1.4597579334244055e-45

# %%
res3.max()
# Out:
# -62141173992.58456

# %%
(np.exp(res3/1e10+27)/4e2).max()
# Out:
# 2661546.901469018

# %%
L_stars2[2], alphas2[10]
# Out:
# (5.179474679231224e+40, -0.2828571428571428)

# %%
fig

# %%
res8 = np.load('res8.npy')
alphas8 = np.linspace(-0.99, 0., 15)
L_stars8 = np.logspace(40, 45, 15)
log_L8 = np.linspace(40, 45 ,15)

# %%
10**log_L8[7], alphas8[5]
# Out:
# (3.162277660168379e+42, -0.6364285714285713)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L8, alphas8, np.exp(res8/1e10+27)/4e2,cmap=mpl.cm.viridis,
                norm=colors.PowerNorm(gamma=10),
                shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L8[7], alphas8[5], color='red')
ax.annotate("$\\alpha=-0.64$\n$L^*=3.16\\times 10 ^ {42}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^3)=1.31\\times10^{9}$",
            xy=(log_L8[7], alphas8[5]),
            xytext=(41, -0.6), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n 1e3.jpeg', dpi=300)

# %%
fig

# %%
res9 = np.load('res9.npy')
alphas9 = np.linspace(-0.99, 0., 15)
L_stars9 = np.logspace(40, 45, 15)
log_L9 = np.linspace(40, 45 ,15)

# %%
res9.max()
# Out:
# -4469105.852935058

# %%
alphas9
# Out:
# array([-0.99      , -0.91928571, -0.84857143, -0.77785714, -0.70714286,
#        -0.63642857, -0.56571429, -0.495     , -0.42428571, -0.35357143,
#        -0.28285714, -0.21214286, -0.14142857, -0.07071429,  0.        ])

# %%
log_L9[10], alphas9[14]
# Out:
# (43.57142857142857, 0.0)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))
img = ax.pcolor(log_L8, alphas8, np.exp(res8/1e10+27)/4e2,cmap=mpl.cm.viridis,
                norm=colors.PowerNorm(gamma=10),
                shading='auto')
#fig.colorbar(img, ax=ax)
ax.scatter(log_L9[10], alphas9[14], color='red')
ax.annotate("$\\alpha=-0.64$\n$L^*=3.16\\times 10 ^ {42}\mathrm{erg/s}$\n$p_{\mathrm{max}}(N=n\\times10^3)=1.33\\times10^{9}$",
            xy=(log_L9[10], alphas9[14]),
            xytext=(41, -0.6), xycoords='data')
ax.set_ylabel("$\\alpha$")
ax.set_xlabel("$\log[ L^*/(\mathrm{erg/s})]$")
#fig.colorbar(img, ax=ax)
plt.tight_layout()
fig.savefig('MLE N=n.jpeg', dpi=300)
